# %%
# Import Modules
import time
import math
import matplotlib.pyplot as plt
import pygame
import random
import numpy as np
from pygame.locals import *
from swarm import *
from DDPG import *
from xvfbwrapper import Xvfb
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.14)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Start virtual display
vdisplay = Xvfb()
vdisplay.start()


# Simulation Parameters
number_of_particles = 24
number_of_axes      = 2
delta_t             = 0.1
t_final             = 5000
screen_size         = [3000,1800]
initial_location    = [screen_size[0]/2,screen_size[1]/2]
list_min_distance   = []
list_ave_distance   = []
xtrg                = [initial_location[ii] + np.random.randint([900,1400])[ii] for ii in range(number_of_axes)]
particles           = swarm(number_of_particles=number_of_particles, screensize=screen_size, target_location=xtrg,
                            display=True, CommRng=100, dim=number_of_axes)
rlagent             = [key for key in particles.member.keys() if particles.member[key]['role']=='rlagent'][0]
leader              = particles.leader
numberofneighbour   = 5
numberofleader      = 1
clock               = pygame.time.Clock()
numberofepochs      = 100000
state               = []
newstate            = []
train               = False
# Out:
# -----------------------
# SUMMARY FOR PARTICLES
# -----------------------
#
# particle id :  0
# role        :  leader
# target      :  target
# wghts       :  [ 0.  0.  0.  0. 10.  0.]
# dist2wp     :  2164.935321820959
# -----------------------
# particle id :  1
# role        :  rlagent
# target      :  leader
# wghts       :  no weights
# dist2wp     :  317.45123940060665
# -----------------------
# particle id :  2
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  289.1661989884258
# -----------------------
# particle id :  3
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  100.82463963092222
# -----------------------
# particle id :  4
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  174.48140970893533
# -----------------------
# particle id :  5
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  130.79789541260493
# -----------------------
# particle id :  6
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  158.06800622255054
# -----------------------
# particle id :  7
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  461.8208443334792
# -----------------------
# particle id :  8
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  279.31005714355166
# -----------------------
# particle id :  9
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  502.6024120760178
# -----------------------
# particle id :  10
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  484.03628756759144
# -----------------------
# particle id :  11
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  288.744031629945
# -----------------------
# particle id :  12
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  290.697876126054
# -----------------------
# particle id :  13
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  279.11784287413565
# -----------------------
# particle id :  14
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  287.23330795583905
# -----------------------
# particle id :  15
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  158.06581798657177
# -----------------------
# particle id :  16
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  82.6341151020665
# -----------------------
# particle id :  17
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  194.91139741117257
# -----------------------
# particle id :  18
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  254.1891423590198
# -----------------------
# particle id :  19
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  108.69456456002231
# -----------------------
# particle id :  20
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  343.74401493753805
# -----------------------
# particle id :  21
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  491.9955024981861
# -----------------------
# particle id :  22
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  407.4902430824868
# -----------------------
# particle id :  23
# role        :  follower
# target      :  leader
# wghts       :  [-8.527, 9.441, -1.126, 7.908, 5.326, -3.06]
# dist2wp     :  131.7316788957435
# -----------------------

# %%
# Instance of DDPG is created.
print('----------------------------------------------------------------------------')
print('There will be %s states, %s for relative velocity, %s for relative position' % \
      (particles.dim*(numberofneighbour+numberofleader)*2,\
      particles.dim*(numberofneighbour+numberofleader),\
      particles.dim*(numberofneighbour+numberofleader)))
print('----------------------------------------------------------------------------')
### Some states are from the closest leader ###
print('%s of the states are gathered from the closest leader of the swarm' % (numberofleader*particles.dim*2))
print('----------------------------------------------------------------------------')
myagent           = Agent(actor_network  = {'nn'          :[80,40],
                                            'activation'  :'relu',
                                            'initializer' :glorot_normal,
                                            'optimizer'   :Adam(learning_rate=0.001)}, 
                          critic_network = {'nn'          :[40,80],
                                            'concat'      :[40,80,20],
                                            'activation'  :'relu',
                                            'initializer' :glorot_normal,
                                            'optimizer'   :Adam(learning_rate=0.002)},
                          loadsavedfile=False,
                          disablenoise=False,
                          lowerBound=-3,upperBound=3,
                          numberOfActions=number_of_axes,
                          numberOfStates=particles.dim*(numberofneighbour+numberofleader)*2,
                          buffer_capacity= 250000, batch_size= 256,
                          tau= 0.001, gamma= 0.95, annealing= 10000)
# Out:
# ----------------------------------------------------------------------------
# There will be 24 states, 12 for relative velocity, 12 for relative position
# ----------------------------------------------------------------------------
# 4 of the states are gathered from the closest leader of the swarm
# ----------------------------------------------------------------------------
# Size of State Space ->  24
# Size of Action Space ->  2
# Max Value of Action ->  3
# Min Value of Action ->  -3

# %%
#States are appended to the "states list"
def stateappend(state):
    state = []
    for relpos,relvel in zip(list(particles.member[rlagent]['relative_position'].values())[0:numberofneighbour],\
                             list(particles.member[rlagent]['relative_velocity'].values())[0:numberofneighbour]):
        for pos,vel in zip(relpos.values(),relvel.values()):
            state.append(pos)
            state.append(vel)

    for relpos,relvel in zip(list(particles.member[rlagent]['distance2leader'].values()),\
                             list(particles.member[rlagent]['velocity2leader'].values())):
        state.append(relpos)
        state.append(relvel)
    state = np.array(state)
    return state

# %%
# Reward Function 
def rewardfunction(dist2leader,dist2closest,score,t):
    if dist2leader >= 500.0 or dist2closest <=2.0:
        reward = -10000
    else:
        if dist2closest > 2.0 and dist2closest < 10.0:
            reward = dist2closest**3 - dist2leader
        else:
            reward = 1000 - dist2closest**1.5 - dist2leader
    
    reward = reward / 10000
    score = score + reward
    t  = t + delta_t
    
    if score <= -100 or reward <= -1 or t >= t_final:
        done = True
    else:
        done = False
    
    return reward, score, done, t

# %%
# Main Function
for epoch in range(numberofepochs):
    xtrg        = [np.random.randint(screen_size)[ii] for ii in range(number_of_axes)]
    particles.__init__(number_of_particles=number_of_particles,screensize=screen_size,target_location=xtrg,
                       display=True,CommRng=100,summary=False)
    rlagent     = [key for key in particles.member.keys() if particles.member[key]['role']=='rlagent'][0]
    state       = stateappend(state)
    done        = False
    t, score    = 0 , 0 
    myagent.mtd = False
    myagent.msd = False
    while not done:
        particles.rulebasedalgo()
        action = myagent.policy(state.reshape(1,myagent.numberOfStates))

        for dim in range(particles.dim):
            particles.member[rlagent]['deltavel'][str(dim)] = action[int(dim)]

        particles.update(keepGoing=not done)
        distance = {'2leader'  : (lambda x: np.sqrt(x[0]**2+x[1]**2))\
                                 (list(particles.member[rlagent]['distance2leader'].values())),
                    '2closest' : particles.member[rlagent]['abs_distance_sorted'][1]}
        newstate = stateappend(newstate)
        reward, score, done, t = rewardfunction(distance['2leader'],distance['2closest'],score,t)
        myagent.observation    = (state,action,reward,newstate)
        myagent.record_buffer()
        
        state = newstate
        print('ep= %s, act0= %.3f, act1= %.3f, vel0= %.3f, vel1= %.3f, rwd= %0.2f, scr= %0.2f, mt= %0.2f, ms= %0.2f, d2l= %0.2f, d2c= %0.2f, noisevar= %.2f, t= %0.1f' %\
             (epoch,action[0],action[1],particles.member[rlagent]['velocity']['0'],particles.member[rlagent]['velocity']['1'],reward,score,myagent.maxtime,myagent.maxscore,distance['2leader'],distance['2closest'],myagent.noisevariance,t))
        
        if t%100 >= 0.0 and t%100 < delta_t:
            print('\ntarget location changes\n')
            particles.trgt_loc                 = {str(ii) : np.random.randint(screen_size)[ii] for ii in\
                                                            range(particles.dim)}
            particles.targetposition['target'] = particles.trgt_loc

    if done:
        if t >= myagent.maxtime:
            myagent.maxtime  = t
            myagent.mtd      = True
            print('saving models for mtd')
        if score >= myagent.maxscore:
            myagent.maxscore = score
            myagent.msd      =True
            print('saving models for msd')
        if train:
            myagent.save()
            myagent.learn()
    
        print('\n----- New Epoch ----- Epoch: %s\n' % (epoch+1))
            
    print('-----------------------------------------------------------------')
# Out:
# ep= 0, act0= 2.981, act1= -3.000, vel0= 8.550, vel1= 3.638, rwd= 0.05, scr= 0.05, mt= 0.00, ms= 0.00, d2l= 181.34, d2c= 43.59, noisevar= 0.60, t= 0.1
# ep= 0, act0= 1.343, act1= -1.165, vel0= 8.684, vel1= 3.522, rwd= 0.05, scr= 0.11, mt= 0.00, ms= 0.00, d2l= 182.03, d2c= 43.51, noisevar= 0.60, t= 0.2
# ep= 0, act0= -2.488, act1= -3.000, vel0= 8.435, vel1= 3.222, rwd= 0.05, scr= 0.16, mt= 0.00, ms= 0.00, d2l= 182.75, d2c= 43.55, noisevar= 0.60, t= 0.3
# ep= 0, act0= -2.420, act1= -3.000, vel0= 8.193, vel1= 2.922, rwd= 0.05, scr= 0.21, mt= 0.00, ms= 0.00, d2l= 183.51, d2c= 43.71, noisevar= 0.60, t= 0.4
# ep= 0, act0= -3.000, act1= -2.976, vel0= 7.893, vel1= 2.624, rwd= 0.05, scr= 0.26, mt= 0.00, ms= 0.00, d2l= 184.31, d2c= 43.98, noisevar= 0.60, t= 0.5
# ep= 0, act0= -3.000, act1= -2.285, vel0= 7.593, vel1= 2.396, rwd= 0.05, scr= 0.32, mt= 0.00, ms= 0.00, d2l= 185.16, d2c= 44.35, noisevar= 0.60, t= 0.6
# ep= 0, act0= -2.588, act1= -3.000, vel0= 7.335, vel1= 2.096, rwd= 0.05, scr= 0.37, mt= 0.00, ms= 0.00, d2l= 186.05, d2c= 42.87, noisevar= 0.60, t= 0.7
# ep= 0, act0= 1.989, act1= -3.000, vel0= 7.533, vel1= 1.796, rwd= 0.06, scr= 0.43, mt= 0.00, ms= 0.00, d2l= 186.93, d2c= 40.54, noisevar= 0.60, t= 0.8
# ep= 0, act0= 0.596, act1= -3.000, vel0= 7.593, vel1= 1.496, rwd= 0.06, scr= 0.48, mt= 0.00, ms= 0.00, d2l= 187.83, d2c= 38.25, noisevar= 0.60, t= 0.9
# ep= 0, act0= 1.085, act1= -2.403, vel0= 7.702, vel1= 1.256, rwd= 0.06, scr= 0.54, mt= 0.00, ms= 0.00, d2l= 188.73, d2c= 36.02, noisevar= 0.60, t= 1.0
# ep= 0, act0= -0.576, act1= -2.327, vel0= 7.644, vel1= 1.023, rwd= 0.06, scr= 0.60, mt= 0.00, ms= 0.00, d2l= 189.66, d2c= 33.84, noisevar= 0.60, t= 1.1
# ep= 0, act0= -0.400, act1= -3.000, vel0= 7.604, vel1= 0.723, rwd= 0.06, scr= 0.67, mt= 0.00, ms= 0.00, d2l= 190.61, d2c= 31.73, noisevar= 0.60, t= 1.2
# ep= 0, act0= -2.713, act1= -2.515, vel0= 7.333, vel1= 0.471, rwd= 0.06, scr= 0.73, mt= 0.00, ms= 0.00, d2l= 191.61, d2c= 29.70, noisevar= 0.60, t= 1.3
# ep= 0, act0= -2.401, act1= -2.981, vel0= 7.093, vel1= 0.173, rwd= 0.07, scr= 0.80, mt= 0.00, ms= 0.00, d2l= 192.65, d2c= 27.75, noisevar= 0.60, t= 1.4
# ep= 0, act0= -2.702, act1= -3.000, vel0= 6.822, vel1= -0.127, rwd= 0.07, scr= 0.86, mt= 0.00, ms= 0.00, d2l= 193.74, d2c= 25.91, noisevar= 0.60, t= 1.5
# ep= 0, act0= -1.918, act1= -3.000, vel0= 6.631, vel1= -0.427, rwd= 0.07, scr= 0.93, mt= 0.00, ms= 0.00, d2l= 194.86, d2c= 24.20, noisevar= 0.60, t= 1.6
# ep= 0, act0= -3.000, act1= -3.000, vel0= 6.331, vel1= -0.727, rwd= 0.07, scr= 1.00, mt= 0.00, ms= 0.00, d2l= 196.04, d2c= 22.65, noisevar= 0.60, t= 1.7
# ep= 0, act0= -2.321, act1= -3.000, vel0= 6.098, vel1= -1.027, rwd= 0.07, scr= 1.07, mt= 0.00, ms= 0.00, d2l= 197.27, d2c= 21.28, noisevar= 0.60, t= 1.8
# ep= 0, act0= -3.000, act1= -1.389, vel0= 5.798, vel1= -1.166, rwd= 0.07, scr= 1.14, mt= 0.00, ms= 0.00, d2l= 198.54, d2c= 20.12, noisevar= 0.60, t= 1.9
# ep= 0, act0= -2.326, act1= -3.000, vel0= 5.566, vel1= -1.466, rwd= 0.07, scr= 1.22, mt= 0.00, ms= 0.00, d2l= 199.87, d2c= 19.22, noisevar= 0.60, t= 2.0
# ep= 0, act0= -3.000, act1= -2.798, vel0= 5.266, vel1= -1.746, rwd= 0.07, scr= 1.29, mt= 0.00, ms= 0.00, d2l= 201.24, d2c= 18.62, noisevar= 0.60, t= 2.1
# ep= 0, act0= -3.000, act1= -2.531, vel0= 4.966, vel1= -1.999, rwd= 0.07, scr= 1.36, mt= 0.00, ms= 0.00, d2l= 202.67, d2c= 21.27, noisevar= 0.60, t= 2.2
# ep= 0, act0= -3.000, act1= -3.000, vel0= 4.666, vel1= -2.299, rwd= 0.07, scr= 1.43, mt= 0.00, ms= 0.00, d2l= 204.16, d2c= 23.06, noisevar= 0.60, t= 2.3
# ep= 0, act0= -3.000, act1= -3.000, vel0= 4.366, vel1= -2.599, rwd= 0.07, scr= 1.50, mt= 0.00, ms= 0.00, d2l= 205.70, d2c= 21.26, noisevar= 0.60, t= 2.4
# ep= 0, act0= -3.000, act1= -3.000, vel0= 4.066, vel1= -2.899, rwd= 0.07, scr= 1.57, mt= 0.00, ms= 0.00, d2l= 207.29, d2c= 18.49, noisevar= 0.60, t= 2.5
# ep= 0, act0= -3.000, act1= -2.695, vel0= 3.766, vel1= -3.168, rwd= 0.07, scr= 1.64, mt= 0.00, ms= 0.00, d2l= 208.94, d2c= 21.12, noisevar= 0.60, t= 2.6
# ep= 0, act0= -3.000, act1= -2.708, vel0= 3.466, vel1= -3.439, rwd= 0.07, scr= 1.71, mt= 0.00, ms= 0.00, d2l= 210.65, d2c= 20.77, noisevar= 0.60, t= 2.7
# ep= 0, act0= -2.850, act1= -3.000, vel0= 3.181, vel1= -3.739, rwd= 0.07, scr= 1.78, mt= 0.00, ms= 0.00, d2l= 212.41, d2c= 18.98, noisevar= 0.60, t= 2.8
# ep= 0, act0= -3.000, act1= -2.948, vel0= 2.881, vel1= -4.034, rwd= 0.07, scr= 1.85, mt= 0.00, ms= 0.00, d2l= 214.23, d2c= 21.40, noisevar= 0.60, t= 2.9
# ep= 0, act0= -3.000, act1= -2.638, vel0= 2.581, vel1= -4.298, rwd= 0.07, scr= 1.91, mt= 0.00, ms= 0.00, d2l= 216.10, d2c= 20.65, noisevar= 0.60, t= 3.0
# ep= 0, act0= -3.000, act1= -3.000, vel0= 2.281, vel1= -4.598, rwd= 0.07, scr= 1.99, mt= 0.00, ms= 0.00, d2l= 218.03, d2c= 17.91, noisevar= 0.60, t= 3.1
# ep= 0, act0= -2.807, act1= -3.000, vel0= 2.000, vel1= -4.898, rwd= 0.07, scr= 2.05, mt= 0.00, ms= 0.00, d2l= 220.02, d2c= 20.15, noisevar= 0.60, t= 3.2
# ep= 0, act0= -2.803, act1= -2.884, vel0= 1.720, vel1= -5.186, rwd= 0.07, scr= 2.12, mt= 0.00, ms= 0.00, d2l= 222.06, d2c= 19.03, noisevar= 0.60, t= 3.3
# ep= 0, act0= -3.000, act1= -2.277, vel0= 1.420, vel1= -5.414, rwd= 0.07, scr= 2.19, mt= 0.00, ms= 0.00, d2l= 224.16, d2c= 21.18, noisevar= 0.60, t= 3.4
# ep= 0, act0= -3.000, act1= -2.547, vel0= 1.120, vel1= -5.668, rwd= 0.07, scr= 2.26, mt= 0.00, ms= 0.00, d2l= 226.32, d2c= 19.66, noisevar= 0.60, t= 3.5
# ep= 0, act0= -3.000, act1= -3.000, vel0= 0.820, vel1= -5.968, rwd= 0.07, scr= 2.33, mt= 0.00, ms= 0.00, d2l= 228.53, d2c= 16.58, noisevar= 0.60, t= 3.6
# ep= 0, act0= -2.354, act1= -2.960, vel0= 0.585, vel1= -6.264, rwd= 0.07, scr= 2.40, mt= 0.00, ms= 0.00, d2l= 230.79, d2c= 18.57, noisevar= 0.60, t= 3.7
# ep= 0, act0= -2.470, act1= -3.000, vel0= 0.338, vel1= -6.564, rwd= 0.07, scr= 2.47, mt= 0.00, ms= 0.00, d2l= 233.11, d2c= 20.64, noisevar= 0.60, t= 3.8
# ep= 0, act0= -3.000, act1= -2.327, vel0= 0.038, vel1= -6.797, rwd= 0.07, scr= 2.54, mt= 0.00, ms= 0.00, d2l= 235.48, d2c= 18.48, noisevar= 0.60, t= 3.9
# ep= 0, act0= -2.798, act1= -3.000, vel0= -0.242, vel1= -7.097, rwd= 0.07, scr= 2.60, mt= 0.00, ms= 0.00, d2l= 237.91, d2c= 20.48, noisevar= 0.60, t= 4.0
# ep= 0, act0= 2.342, act1= -2.205, vel0= -0.008, vel1= -7.318, rwd= 0.07, scr= 2.67, mt= 0.00, ms= 0.00, d2l= 240.35, d2c= 18.02, noisevar= 0.60, t= 4.1
# ep= 0, act0= 3.000, act1= -3.000, vel0= 0.292, vel1= -7.618, rwd= 0.07, scr= 2.74, mt= 0.00, ms= 0.00, d2l= 242.78, d2c= 20.00, noisevar= 0.60, t= 4.2
# ep= 0, act0= 3.000, act1= -2.296, vel0= 0.592, vel1= -7.847, rwd= 0.07, scr= 2.81, mt= 0.00, ms= 0.00, d2l= 245.21, d2c= 17.26, noisevar= 0.60, t= 4.3
# ep= 0, act0= 3.000, act1= -2.905, vel0= 0.892, vel1= -8.138, rwd= 0.07, scr= 2.87, mt= 0.00, ms= 0.00, d2l= 247.64, d2c= 19.26, noisevar= 0.60, t= 4.4
# ep= 0, act0= -2.389, act1= -2.653, vel0= 0.653, vel1= -8.403, rwd= 0.07, scr= 2.94, mt= 0.00, ms= 0.00, d2l= 250.12, d2c= 16.23, noisevar= 0.60, t= 4.5
# ep= 0, act0= -2.925, act1= -3.000, vel0= 0.361, vel1= -8.703, rwd= 0.07, scr= 3.01, mt= 0.00, ms= 0.00, d2l= 252.66, d2c= 18.20, noisevar= 0.60, t= 4.6
# ep= 0, act0= -2.082, act1= -2.626, vel0= 0.152, vel1= -8.966, rwd= 0.07, scr= 3.07, mt= 0.00, ms= 0.00, d2l= 255.24, d2c= 20.21, noisevar= 0.60, t= 4.7
# ep= 0, act0= -3.000, act1= -2.567, vel0= -0.148, vel1= -9.222, rwd= 0.07, scr= 3.14, mt= 0.00, ms= 0.00, d2l= 257.89, d2c= 16.67, noisevar= 0.60, t= 4.8
# ep= 0, act0= -3.000, act1= -2.971, vel0= -0.448, vel1= -9.520, rwd= 0.07, scr= 3.21, mt= 0.00, ms= 0.00, d2l= 260.59, d2c= 18.66, noisevar= 0.60, t= 4.9
# ep= 0, act0= -2.600, act1= -3.000, vel0= -0.708, vel1= -9.820, rwd= 0.06, scr= 3.27, mt= 0.00, ms= 0.00, d2l= 263.34, d2c= 20.66, noisevar= 0.60, t= 5.0
# ep= 0, act0= -2.725, act1= -2.923, vel0= -0.980, vel1= -10.112, rwd= 0.07, scr= 3.34, mt= 0.00, ms= 0.00, d2l= 266.15, d2c= 17.00, noisevar= 0.60, t= 5.1
# ep= 0, act0= -3.000, act1= -3.000, vel0= -1.280, vel1= -10.412, rwd= 0.06, scr= 3.40, mt= 0.00, ms= 0.00, d2l= 269.02, d2c= 18.97, noisevar= 0.60, t= 5.2
# ep= 0, act0= -1.854, act1= -3.000, vel0= -1.466, vel1= -10.712, rwd= 0.06, scr= 3.47, mt= 0.00, ms= 0.00, d2l= 271.94, d2c= 20.93, noisevar= 0.60, t= 5.3
# ep= 0, act0= -3.000, act1= -2.966, vel0= -1.766, vel1= -11.008, rwd= 0.07, scr= 3.53, mt= 0.00, ms= 0.00, d2l= 274.91, d2c= 17.21, noisevar= 0.60, t= 5.4
# ep= 0, act0= -2.340, act1= -3.000, vel0= -2.000, vel1= -11.308, rwd= 0.06, scr= 3.59, mt= 0.00, ms= 0.00, d2l= 277.93, d2c= 19.14, noisevar= 0.60, t= 5.5
# ep= 0, act0= -2.095, act1= -2.849, vel0= -2.209, vel1= -11.593, rwd= 0.07, scr= 3.66, mt= 0.00, ms= 0.00, d2l= 281.01, d2c= 15.42, noisevar= 0.60, t= 5.6
# ep= 0, act0= 2.939, act1= -3.000, vel0= -1.915, vel1= -11.893, rwd= 0.06, scr= 3.72, mt= 0.00, ms= 0.00, d2l= 284.08, d2c= 17.35, noisevar= 0.60, t= 5.7
# ep= 0, act0= 1.968, act1= -2.517, vel0= -1.718, vel1= -12.145, rwd= 0.06, scr= 3.79, mt= 0.00, ms= 0.00, d2l= 287.16, d2c= 19.30, noisevar= 0.60, t= 5.8
# ep= 0, act0= 3.000, act1= -2.796, vel0= -1.418, vel1= -12.425, rwd= 0.06, scr= 3.85, mt= 0.00, ms= 0.00, d2l= 290.24, d2c= 15.77, noisevar= 0.60, t= 5.9
# ep= 0, act0= 2.979, act1= -3.000, vel0= -1.120, vel1= -12.725, rwd= 0.06, scr= 3.92, mt= 0.00, ms= 0.00, d2l= 293.33, d2c= 17.77, noisevar= 0.60, t= 6.0
# ep= 0, act0= 2.459, act1= -2.825, vel0= -0.875, vel1= -13.007, rwd= 0.06, scr= 3.98, mt= 0.00, ms= 0.00, d2l= 296.41, d2c= 18.57, noisevar= 0.60, t= 6.1
# ep= 0, act0= 3.000, act1= -2.888, vel0= -0.575, vel1= -13.296, rwd= 0.06, scr= 4.04, mt= 0.00, ms= 0.00, d2l= 299.50, d2c= 17.18, noisevar= 0.60, t= 6.2
# ep= 0, act0= 3.000, act1= -2.640, vel0= -0.275, vel1= -13.560, rwd= 0.06, scr= 4.10, mt= 0.00, ms= 0.00, d2l= 302.59, d2c= 19.18, noisevar= 0.60, t= 6.3
# ep= 0, act0= 2.452, act1= -2.871, vel0= -0.029, vel1= -13.847, rwd= 0.06, scr= 4.16, mt= 0.00, ms= 0.00, d2l= 305.69, d2c= 15.75, noisevar= 0.60, t= 6.4
# ep= 0, act0= 3.000, act1= -3.000, vel0= 0.271, vel1= -14.147, rwd= 0.06, scr= 4.23, mt= 0.00, ms= 0.00, d2l= 308.79, d2c= 17.83, noisevar= 0.60, t= 6.5
# ep= 0, act0= 3.000, act1= -2.970, vel0= 0.571, vel1= -14.444, rwd= 0.06, scr= 4.29, mt= 0.00, ms= 0.00, d2l= 311.89, d2c= 16.44, noisevar= 0.60, t= 6.6
# ep= 0, act0= -2.667, act1= -2.845, vel0= 0.304, vel1= -14.728, rwd= 0.06, scr= 4.35, mt= 0.00, ms= 0.00, d2l= 315.05, d2c= 18.06, noisevar= 0.60, t= 6.7
# ep= 0, act0= 0.366, act1= -2.769, vel0= 0.341, vel1= -15.005, rwd= 0.06, scr= 4.41, mt= 0.00, ms= 0.00, d2l= 318.23, d2c= 17.05, noisevar= 0.60, t= 6.8
# ep= 0, act0= 1.744, act1= -3.000, vel0= 0.515, vel1= -15.305, rwd= 0.06, scr= 4.47, mt= 0.00, ms= 0.00, d2l= 321.43, d2c= 18.66, noisevar= 0.60, t= 6.9
# ep= 0, act0= 1.678, act1= -3.000, vel0= 0.683, vel1= -15.605, rwd= 0.06, scr= 4.53, mt= 0.00, ms= 0.00, d2l= 324.65, d2c= 17.29, noisevar= 0.60, t= 7.0
# ep= 0, act0= 3.000, act1= -2.598, vel0= 0.983, vel1= -15.865, rwd= 0.06, scr= 4.59, mt= 0.00, ms= 0.00, d2l= 327.86, d2c= 19.26, noisevar= 0.60, t= 7.1
# ep= 0, act0= 2.745, act1= -2.519, vel0= 1.257, vel1= -16.117, rwd= 0.06, scr= 4.65, mt= 0.00, ms= 0.00, d2l= 331.08, d2c= 15.84, noisevar= 0.60, t= 7.2
# ep= 0, act0= 2.410, act1= -3.000, vel0= 1.498, vel1= -16.417, rwd= 0.06, scr= 4.71, mt= 0.00, ms= 0.00, d2l= 334.31, d2c= 16.91, noisevar= 0.60, t= 7.3
# ep= 0, act0= 2.615, act1= -3.000, vel0= 1.760, vel1= -16.717, rwd= 0.06, scr= 4.77, mt= 0.00, ms= 0.00, d2l= 337.55, d2c= 16.61, noisevar= 0.60, t= 7.4
# ep= 0, act0= 3.000, act1= -3.000, vel0= 2.060, vel1= -17.017, rwd= 0.06, scr= 4.83, mt= 0.00, ms= 0.00, d2l= 340.79, d2c= 17.25, noisevar= 0.60, t= 7.5
# ep= 0, act0= 3.000, act1= -3.000, vel0= 2.360, vel1= -17.317, rwd= 0.06, scr= 4.89, mt= 0.00, ms= 0.00, d2l= 344.04, d2c= 15.94, noisevar= 0.60, t= 7.6
# ep= 0, act0= -3.000, act1= -3.000, vel0= 2.060, vel1= -17.617, rwd= 0.06, scr= 4.94, mt= 0.00, ms= 0.00, d2l= 347.35, d2c= 17.97, noisevar= 0.60, t= 7.7
# ep= 0, act0= -2.130, act1= -2.397, vel0= 1.847, vel1= -17.857, rwd= 0.06, scr= 5.00, mt= 0.00, ms= 0.00, d2l= 350.71, d2c= 16.50, noisevar= 0.60, t= 7.8
# ep= 0, act0= -1.917, act1= -3.000, vel0= 1.655, vel1= -18.157, rwd= 0.06, scr= 5.06, mt= 0.00, ms= 0.00, d2l= 354.11, d2c= 17.65, noisevar= 0.60, t= 7.9
# ep= 0, act0= 0.637, act1= -2.634, vel0= 1.719, vel1= -18.420, rwd= 0.06, scr= 5.12, mt= 0.00, ms= 0.00, d2l= 357.54, d2c= 16.94, noisevar= 0.60, t= 8.0
# ep= 0, act0= 2.870, act1= -2.781, vel0= 2.006, vel1= -18.698, rwd= 0.06, scr= 5.17, mt= 0.00, ms= 0.00, d2l= 360.98, d2c= 17.93, noisevar= 0.60, t= 8.1
# ep= 0, act0= 2.648, act1= -2.751, vel0= 2.270, vel1= -18.973, rwd= 0.06, scr= 5.23, mt= 0.00, ms= 0.00, d2l= 364.42, d2c= 16.49, noisevar= 0.60, t= 8.2
# ep= 0, act0= 3.000, act1= -2.978, vel0= 2.570, vel1= -19.271, rwd= 0.06, scr= 5.29, mt= 0.00, ms= 0.00, d2l= 367.87, d2c= 18.44, noisevar= 0.60, t= 8.3
# ep= 0, act0= 2.396, act1= -3.000, vel0= 2.810, vel1= -19.571, rwd= 0.06, scr= 5.34, mt= 0.00, ms= 0.00, d2l= 371.33, d2c= 17.00, noisevar= 0.60, t= 8.4
# ep= 0, act0= 3.000, act1= -3.000, vel0= 3.110, vel1= -19.871, rwd= 0.06, scr= 5.40, mt= 0.00, ms= 0.00, d2l= 374.80, d2c= 17.16, noisevar= 0.60, t= 8.5
# ep= 0, act0= 3.000, act1= -3.000, vel0= 3.410, vel1= -20.000, rwd= 0.05, scr= 5.45, mt= 0.00, ms= 0.00, d2l= 378.27, d2c= 18.92, noisevar= 0.60, t= 8.6
# ep= 0, act0= 3.000, act1= -3.000, vel0= 3.710, vel1= -20.000, rwd= 0.05, scr= 5.51, mt= 0.00, ms= 0.00, d2l= 381.73, d2c= 17.52, noisevar= 0.60, t= 8.7
# ep= 0, act0= 2.770, act1= -2.552, vel0= 3.987, vel1= -20.000, rwd= 0.05, scr= 5.56, mt= 0.00, ms= 0.00, d2l= 385.18, d2c= 16.19, noisevar= 0.60, t= 8.8
# ep= 0, act0= 2.384, act1= -3.000, vel0= 4.225, vel1= -20.000, rwd= 0.05, scr= 5.61, mt= 0.00, ms= 0.00, d2l= 388.63, d2c= 18.22, noisevar= 0.60, t= 8.9
# ep= 0, act0= 2.870, act1= -2.723, vel0= 4.512, vel1= -20.000, rwd= 0.05, scr= 5.67, mt= 0.00, ms= 0.00, d2l= 392.07, d2c= 16.91, noisevar= 0.60, t= 9.0
# ep= 0, act0= 3.000, act1= -3.000, vel0= 4.812, vel1= -20.000, rwd= 0.05, scr= 5.72, mt= 0.00, ms= 0.00, d2l= 395.51, d2c= 17.21, noisevar= 0.60, t= 9.1
# ep= 0, act0= 2.589, act1= -2.699, vel0= 5.071, vel1= -20.000, rwd= 0.05, scr= 5.77, mt= 0.00, ms= 0.00, d2l= 398.93, d2c= 18.48, noisevar= 0.60, t= 9.2
# ep= 0, act0= 3.000, act1= -3.000, vel0= 5.371, vel1= -20.000, rwd= 0.05, scr= 5.83, mt= 0.00, ms= 0.00, d2l= 402.35, d2c= 17.23, noisevar= 0.60, t= 9.3
# ep= 0, act0= 3.000, act1= -3.000, vel0= 5.671, vel1= -20.000, rwd= 0.05, scr= 5.88, mt= 0.00, ms= 0.00, d2l= 405.76, d2c= 16.05, noisevar= 0.60, t= 9.4
# ep= 0, act0= 2.473, act1= -3.000, vel0= 5.919, vel1= -20.000, rwd= 0.05, scr= 5.93, mt= 0.00, ms= 0.00, d2l= 409.17, d2c= 18.22, noisevar= 0.60, t= 9.5
# ep= 0, act0= 3.000, act1= -3.000, vel0= 6.219, vel1= -20.000, rwd= 0.05, scr= 5.98, mt= 0.00, ms= 0.00, d2l= 412.57, d2c= 17.05, noisevar= 0.60, t= 9.6
# ep= 0, act0= 2.499, act1= -2.878, vel0= 6.469, vel1= -20.000, rwd= 0.05, scr= 6.03, mt= 0.00, ms= 0.00, d2l= 415.96, d2c= 16.51, noisevar= 0.60, t= 9.7
# ep= 0, act0= 2.724, act1= -3.000, vel0= 6.741, vel1= -20.000, rwd= 0.05, scr= 6.08, mt= 0.00, ms= 0.00, d2l= 419.34, d2c= 18.78, noisevar= 0.60, t= 9.8
# ep= 0, act0= 3.000, act1= -3.000, vel0= 7.041, vel1= -20.000, rwd= 0.05, scr= 6.13, mt= 0.00, ms= 0.00, d2l= 422.72, d2c= 17.67, noisevar= 0.60, t= 9.9
# ep= 0, act0= 2.877, act1= -2.849, vel0= 7.329, vel1= -20.000, rwd= 0.05, scr= 6.18, mt= 0.00, ms= 0.00, d2l= 426.08, d2c= 16.61, noisevar= 0.60, t= 10.0
# ep= 0, act0= 2.615, act1= -3.000, vel0= 7.590, vel1= -20.000, rwd= 0.05, scr= 6.23, mt= 0.00, ms= 0.00, d2l= 429.44, d2c= 17.87, noisevar= 0.60, t= 10.1
# ep= 0, act0= 3.000, act1= -2.721, vel0= 7.890, vel1= -20.000, rwd= 0.05, scr= 6.28, mt= 0.00, ms= 0.00, d2l= 432.79, d2c= 16.85, noisevar= 0.60, t= 10.2
# ep= 0, act0= 3.000, act1= -3.000, vel0= 8.190, vel1= -20.000, rwd= 0.05, scr= 6.33, mt= 0.00, ms= 0.00, d2l= 436.13, d2c= 16.99, noisevar= 0.60, t= 10.3
# ep= 0, act0= 3.000, act1= -3.000, vel0= 8.490, vel1= -20.000, rwd= 0.05, scr= 6.38, mt= 0.00, ms= 0.00, d2l= 439.46, d2c= 18.16, noisevar= 0.60, t= 10.4
# ep= 0, act0= 2.484, act1= -2.080, vel0= 8.738, vel1= -20.000, rwd= 0.05, scr= 6.43, mt= 0.00, ms= 0.00, d2l= 442.79, d2c= 17.21, noisevar= 0.60, t= 10.5
# ep= 0, act0= 2.909, act1= -3.000, vel0= 9.029, vel1= -20.000, rwd= 0.05, scr= 6.48, mt= 0.00, ms= 0.00, d2l= 446.11, d2c= 16.30, noisevar= 0.60, t= 10.6
# ep= 0, act0= 3.000, act1= -1.850, vel0= 9.329, vel1= -20.000, rwd= 0.05, scr= 6.53, mt= 0.00, ms= 0.00, d2l= 449.41, d2c= 18.77, noisevar= 0.60, t= 10.7
# ep= 0, act0= 3.000, act1= -2.756, vel0= 9.629, vel1= -20.000, rwd= 0.05, scr= 6.57, mt= 0.00, ms= 0.00, d2l= 452.71, d2c= 17.88, noisevar= 0.60, t= 10.8
# ep= 0, act0= 2.993, act1= -2.783, vel0= 9.929, vel1= -20.000, rwd= 0.05, scr= 6.62, mt= 0.00, ms= 0.00, d2l= 455.99, d2c= 17.03, noisevar= 0.60, t= 10.9
# ep= 0, act0= 3.000, act1= -1.705, vel0= 10.229, vel1= -20.000, rwd= 0.05, scr= 6.67, mt= 0.00, ms= 0.00, d2l= 459.27, d2c= 16.26, noisevar= 0.60, t= 11.0
# ep= 0, act0= 0.780, act1= -2.947, vel0= 10.307, vel1= -20.000, rwd= 0.05, scr= 6.71, mt= 0.00, ms= 0.00, d2l= 462.56, d2c= 18.82, noisevar= 0.60, t= 11.1
# ep= 0, act0= 1.641, act1= -3.000, vel0= 10.471, vel1= -20.000, rwd= 0.05, scr= 6.76, mt= 0.00, ms= 0.00, d2l= 465.84, d2c= 18.00, noisevar= 0.60, t= 11.2
# ep= 0, act0= 3.000, act1= -3.000, vel0= 10.771, vel1= -20.000, rwd= 0.05, scr= 6.81, mt= 0.00, ms= 0.00, d2l= 469.12, d2c= 17.21, noisevar= 0.60, t= 11.3
# ep= 0, act0= 1.989, act1= -3.000, vel0= 10.970, vel1= -20.000, rwd= 0.05, scr= 6.85, mt= 0.00, ms= 0.00, d2l= 472.39, d2c= 16.46, noisevar= 0.60, t= 11.4
# ep= 0, act0= 3.000, act1= -3.000, vel0= 11.270, vel1= -20.000, rwd= 0.04, scr= 6.90, mt= 0.00, ms= 0.00, d2l= 475.65, d2c= 18.04, noisevar= 0.60, t= 11.5
# ep= 0, act0= 2.955, act1= -3.000, vel0= 11.565, vel1= -20.000, rwd= 0.04, scr= 6.94, mt= 0.00, ms= 0.00, d2l= 478.91, d2c= 17.33, noisevar= 0.60, t= 11.6
# ep= 0, act0= 2.916, act1= -2.723, vel0= 11.857, vel1= -20.000, rwd= 0.04, scr= 6.99, mt= 0.00, ms= 0.00, d2l= 482.15, d2c= 16.65, noisevar= 0.60, t= 11.7
# ep= 0, act0= 2.343, act1= -3.000, vel0= 12.091, vel1= -20.000, rwd= 0.04, scr= 7.03, mt= 0.00, ms= 0.00, d2l= 485.39, d2c= 17.39, noisevar= 0.60, t= 11.8
# ep= 0, act0= 2.777, act1= -3.000, vel0= 12.369, vel1= -20.000, rwd= 0.04, scr= 7.07, mt= 0.00, ms= 0.00, d2l= 488.62, d2c= 16.96, noisevar= 0.60, t= 11.9
# ep= 0, act0= 3.000, act1= -3.000, vel0= 12.669, vel1= -20.000, rwd= 0.04, scr= 7.12, mt= 0.00, ms= 0.00, d2l= 491.84, d2c= 16.64, noisevar= 0.60, t= 12.0
# ep= 0, act0= 3.000, act1= -2.932, vel0= 12.969, vel1= -20.000, rwd= 0.04, scr= 7.16, mt= 0.00, ms= 0.00, d2l= 495.06, d2c= 17.83, noisevar= 0.60, t= 12.1
# ep= 0, act0= 3.000, act1= -3.000, vel0= 13.269, vel1= -20.000, rwd= 0.04, scr= 7.20, mt= 0.00, ms= 0.00, d2l= 498.26, d2c= 17.26, noisevar= 0.60, t= 12.2
# ep= 0, act0= 2.830, act1= -3.000, vel0= 13.552, vel1= -20.000, rwd= -1.00, scr= 6.20, mt= 0.00, ms= 0.00, d2l= 501.45, d2c= 16.72, noisevar= 0.60, t= 12.3
# saving models for mtd
# saving models for msd
#
# ----- New Epoch ----- Epoch: 1
#
# -----------------------------------------------------------------
# ep= 1, act0= 2.981, act1= -3.000, vel0= 19.681, vel1= -20.000, rwd= -0.03, scr= -0.03, mt= 12.30, ms= 6.20, d2l= 425.12, d2c= 92.44, noisevar= 0.60, t= 0.1
# ep= 1, act0= 2.472, act1= -3.000, vel0= 19.928, vel1= -20.000, rwd= -0.03, scr= -0.06, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 0.2
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.09, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 0.3
# ep= 1, act0= 2.070, act1= -2.552, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.13, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 0.4
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.16, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 0.5
# ep= 1, act0= 2.633, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.19, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 0.6
# ep= 1, act0= 3.000, act1= -2.993, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.22, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 0.7
# ep= 1, act0= 3.000, act1= -2.934, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.25, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 0.8
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.28, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 0.9
# ep= 1, act0= 2.811, act1= -2.451, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.31, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 1.0
# ep= 1, act0= 3.000, act1= -2.693, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.35, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 1.1
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.38, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 1.2
# ep= 1, act0= 2.200, act1= -2.595, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.41, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 1.3
# ep= 1, act0= 2.971, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.44, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 1.4
# ep= 1, act0= 2.614, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.47, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 1.5
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.50, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 1.6
# ep= 1, act0= 3.000, act1= -2.075, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.53, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 1.7
# ep= 1, act0= 2.790, act1= -2.558, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.57, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 1.8
# ep= 1, act0= 3.000, act1= -2.443, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.60, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 1.9
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.63, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 2.0
# ep= 1, act0= 3.000, act1= -2.633, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.66, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 2.1
# ep= 1, act0= 3.000, act1= -2.660, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.69, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 2.2
# ep= 1, act0= 1.857, act1= -2.550, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.72, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 2.3
# ep= 1, act0= 3.000, act1= -2.579, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.75, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 2.4
# ep= 1, act0= 2.887, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.79, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 2.5
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.82, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 2.6
# ep= 1, act0= 1.745, act1= -2.770, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.85, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 2.7
# ep= 1, act0= 3.000, act1= -2.508, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.88, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 2.8
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.91, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 2.9
# ep= 1, act0= 3.000, act1= -2.961, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.94, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 3.0
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -0.97, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 3.1
# ep= 1, act0= 2.074, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.01, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 3.2
# ep= 1, act0= 2.125, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.04, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 3.3
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.07, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 3.4
# ep= 1, act0= 2.711, act1= -2.652, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.10, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 3.5
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.13, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 3.6
# ep= 1, act0= 2.205, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.16, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 3.7
# ep= 1, act0= 2.633, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.19, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 3.8
# ep= 1, act0= 3.000, act1= -2.353, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.22, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 3.9
# ep= 1, act0= 1.739, act1= -2.960, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.26, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 4.0
# ep= 1, act0= 3.000, act1= -2.193, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.29, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 4.1
# ep= 1, act0= 1.708, act1= -1.796, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.32, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 4.2
# ep= 1, act0= 3.000, act1= -2.520, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.35, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 4.3
# ep= 1, act0= 2.451, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.38, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 4.4
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.41, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 4.5
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.44, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 4.6
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.48, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 4.7
# ep= 1, act0= 2.853, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.51, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 4.8
# ep= 1, act0= 3.000, act1= -2.995, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.54, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 4.9
# ep= 1, act0= 3.000, act1= -2.737, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.57, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 5.0
# ep= 1, act0= 2.654, act1= -1.923, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.60, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 5.1
# ep= 1, act0= 2.716, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.63, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 5.2
# ep= 1, act0= 2.952, act1= -2.372, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.66, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 5.3
# ep= 1, act0= 2.264, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.70, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 5.4
# ep= 1, act0= 3.000, act1= -2.745, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.73, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 5.5
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.76, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 5.6
# ep= 1, act0= 2.692, act1= -2.093, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.79, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 5.7
# ep= 1, act0= 2.649, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.82, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 5.8
# ep= 1, act0= 2.788, act1= -2.653, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.85, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 5.9
# ep= 1, act0= 2.780, act1= -2.915, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.88, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 6.0
# ep= 1, act0= 2.867, act1= -2.966, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.92, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 6.1
# ep= 1, act0= 2.770, act1= -2.206, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.95, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 6.2
# ep= 1, act0= 3.000, act1= -2.721, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -1.98, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 6.3
# ep= 1, act0= 2.942, act1= -2.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.01, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 6.4
# ep= 1, act0= 3.000, act1= -2.777, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.04, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 6.5
# ep= 1, act0= 3.000, act1= -2.877, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.07, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 6.6
# ep= 1, act0= 2.926, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.10, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 6.7
# ep= 1, act0= 1.790, act1= -2.536, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.14, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 6.8
# ep= 1, act0= 2.797, act1= -2.830, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.17, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 6.9
# ep= 1, act0= 2.033, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.20, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 7.0
# ep= 1, act0= 2.792, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.23, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 7.1
# ep= 1, act0= 2.593, act1= -2.999, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.26, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 7.2
# ep= 1, act0= 2.326, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.29, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 7.3
# ep= 1, act0= 1.938, act1= -2.304, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.32, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 7.4
# ep= 1, act0= 2.337, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.36, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 7.5
# ep= 1, act0= 2.881, act1= -2.621, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.39, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 7.6
# ep= 1, act0= 2.595, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.42, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 7.7
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.45, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 7.8
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.48, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 7.9
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.51, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 8.0
# ep= 1, act0= 3.000, act1= -1.559, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.54, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 8.1
# ep= 1, act0= 2.738, act1= -2.859, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.58, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 8.2
# ep= 1, act0= 2.235, act1= -2.763, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.61, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 8.3
# ep= 1, act0= 3.000, act1= -1.682, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.64, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 8.4
# ep= 1, act0= 0.743, act1= -2.939, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.67, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 8.5
# ep= 1, act0= 2.232, act1= -1.884, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.70, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 8.6
# ep= 1, act0= 2.730, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.73, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 8.7
# ep= 1, act0= 3.000, act1= -1.995, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.76, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 8.8
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.80, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 8.9
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.83, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 9.0
# ep= 1, act0= 1.219, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.86, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 9.1
# ep= 1, act0= 3.000, act1= -2.793, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.89, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 9.2
# ep= 1, act0= 2.902, act1= -2.732, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.92, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 9.3
# ep= 1, act0= 1.652, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.95, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 9.4
# ep= 1, act0= 3.000, act1= -2.673, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -2.98, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 9.5
# ep= 1, act0= 2.659, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.02, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 9.6
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.05, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 9.7
# ep= 1, act0= 2.865, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.08, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 9.8
# ep= 1, act0= 2.386, act1= -2.424, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.11, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 9.9
# ep= 1, act0= 2.862, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.14, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 10.0
# ep= 1, act0= 1.945, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.17, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 10.1
# ep= 1, act0= 1.916, act1= -2.613, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.20, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 10.2
# ep= 1, act0= 2.040, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.23, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 10.3
# ep= 1, act0= 2.673, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.27, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 10.4
# ep= 1, act0= 3.000, act1= -2.686, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.30, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 10.5
# ep= 1, act0= 2.650, act1= -2.063, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.33, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 10.6
# ep= 1, act0= 2.781, act1= -2.384, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.36, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 10.7
# ep= 1, act0= 3.000, act1= -2.677, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.39, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 10.8
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.42, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 10.9
# ep= 1, act0= 2.917, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.45, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 11.0
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.49, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 11.1
# ep= 1, act0= 2.789, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.52, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 11.2
# ep= 1, act0= 3.000, act1= -2.845, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.55, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 11.3
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.58, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 11.4
# ep= 1, act0= 2.720, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.61, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 11.5
# ep= 1, act0= 2.601, act1= -2.227, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.64, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 11.6
# ep= 1, act0= 2.976, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.67, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 11.7
# ep= 1, act0= 2.909, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.71, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 11.8
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.74, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 11.9
# ep= 1, act0= 2.946, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.77, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 12.0
# ep= 1, act0= 2.492, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.80, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 12.1
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.83, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 12.2
# ep= 1, act0= 3.000, act1= -2.257, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.86, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 12.3
# ep= 1, act0= 2.939, act1= -2.826, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.89, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 12.4
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.93, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 12.5
# ep= 1, act0= 3.000, act1= -1.877, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.96, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 12.6
# ep= 1, act0= 3.000, act1= -2.418, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -3.99, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 12.7
# ep= 1, act0= 2.916, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.02, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 12.8
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.05, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 12.9
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.08, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 13.0
# ep= 1, act0= 2.840, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.11, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 13.1
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.15, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 13.2
# ep= 1, act0= 2.301, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.18, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 13.3
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.21, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 13.4
# ep= 1, act0= 2.741, act1= -2.960, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.24, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 13.5
# ep= 1, act0= 1.688, act1= -2.763, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.27, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 13.6
# ep= 1, act0= 2.221, act1= -2.960, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.30, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 13.7
# ep= 1, act0= 2.891, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.33, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 13.8
# ep= 1, act0= 2.809, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.37, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 13.9
# ep= 1, act0= 3.000, act1= -2.815, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.40, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 14.0
# ep= 1, act0= 2.270, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.43, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 14.1
# ep= 1, act0= 3.000, act1= -2.738, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.46, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 14.2
# ep= 1, act0= 2.470, act1= -2.875, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.49, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 14.3
# ep= 1, act0= 2.587, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.52, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 14.4
# ep= 1, act0= 2.629, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.55, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 14.5
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.59, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 14.6
# ep= 1, act0= 2.720, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.62, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 14.7
# ep= 1, act0= 3.000, act1= -1.268, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.65, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 14.8
# ep= 1, act0= 2.768, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.68, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 14.9
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.71, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 15.0
# ep= 1, act0= 2.975, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.74, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 15.1
# ep= 1, act0= 2.946, act1= -2.803, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.77, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 15.2
# ep= 1, act0= 2.158, act1= -2.776, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.81, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 15.3
# ep= 1, act0= 2.633, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.84, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 15.4
# ep= 1, act0= 3.000, act1= -2.914, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.87, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 15.5
# ep= 1, act0= 1.907, act1= -2.940, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.90, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 15.6
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.93, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 15.7
# ep= 1, act0= 2.548, act1= -2.368, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.96, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 15.8
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -4.99, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 15.9
# ep= 1, act0= 2.985, act1= -2.772, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.03, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 16.0
# ep= 1, act0= 1.792, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.06, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 16.1
# ep= 1, act0= 2.492, act1= -2.778, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.09, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 16.2
# ep= 1, act0= 2.712, act1= -2.110, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.12, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 16.3
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.15, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 16.4
# ep= 1, act0= 3.000, act1= -2.616, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.18, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 16.5
# ep= 1, act0= 3.000, act1= -2.567, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.21, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 16.6
# ep= 1, act0= 2.868, act1= -2.036, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.24, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 16.7
# ep= 1, act0= 3.000, act1= -2.906, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.28, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 16.8
# ep= 1, act0= 3.000, act1= -2.129, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.31, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 16.9
# ep= 1, act0= 2.109, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.34, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 17.0
# ep= 1, act0= 1.815, act1= -2.925, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.37, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 17.1
# ep= 1, act0= 2.674, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.40, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 17.2
# ep= 1, act0= 2.987, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.43, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 17.3
# ep= 1, act0= 2.605, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.46, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 17.4
# ep= 1, act0= 2.860, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.50, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 17.5
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.53, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 17.6
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.56, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 17.7
# ep= 1, act0= 2.894, act1= -2.197, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.59, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 17.8
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.62, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 17.9
# ep= 1, act0= 2.733, act1= -2.584, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.65, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 18.0
# ep= 1, act0= 2.973, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.68, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 18.1
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.72, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 18.2
# ep= 1, act0= 3.000, act1= -2.081, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.75, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 18.3
# ep= 1, act0= 3.000, act1= -3.000, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.78, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 18.4
# ep= 1, act0= 2.409, act1= -1.790, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.81, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 18.5
# ep= 1, act0= 2.666, act1= -2.782, vel0= 20.000, vel1= -20.000, rwd= -0.03, scr= -5.84, mt= 12.30, ms= 6.20, d2l= 425.13, d2c= 92.45, noisevar= 0.60, t= 18.6
# ...
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.237, vel1= 0.215, rwd= 0.04, scr= -45.44, mt= 55.10, ms= 6.20, d2l= 88.17, d2c= 67.33, noisevar= 0.59, t= 166.6
# ep= 9, act0= 2.270, act1= 3.000, vel0= 0.204, vel1= 0.227, rwd= 0.04, scr= -45.40, mt= 55.10, ms= 6.20, d2l= 88.15, d2c= 67.22, noisevar= 0.59, t= 166.7
# ep= 9, act0= 3.000, act1= 2.480, vel0= 0.222, vel1= 0.209, rwd= 0.04, scr= -45.36, mt= 55.10, ms= 6.20, d2l= 88.13, d2c= 67.35, noisevar= 0.59, t= 166.8
# ep= 9, act0= 3.000, act1= 2.934, vel0= 0.230, vel1= 0.222, rwd= 0.04, scr= -45.33, mt= 55.10, ms= 6.20, d2l= 88.11, d2c= 66.82, noisevar= 0.59, t= 166.9
# ep= 9, act0= 2.336, act1= 2.564, vel0= 0.204, vel1= 0.211, rwd= 0.04, scr= -45.29, mt= 55.10, ms= 6.20, d2l= 88.09, d2c= 66.98, noisevar= 0.59, t= 167.0
# ep= 9, act0= 2.672, act1= 2.748, vel0= 0.208, vel1= 0.214, rwd= 0.04, scr= -45.25, mt= 55.10, ms= 6.20, d2l= 88.07, d2c= 66.87, noisevar= 0.59, t= 167.1
# ep= 9, act0= 2.443, act1= 2.697, vel0= 0.199, vel1= 0.213, rwd= 0.04, scr= -45.22, mt= 55.10, ms= 6.20, d2l= 88.05, d2c= 67.01, noisevar= 0.59, t= 167.2
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.220, vel1= 0.226, rwd= 0.04, scr= -45.18, mt= 55.10, ms= 6.20, d2l= 88.03, d2c= 66.89, noisevar= 0.59, t= 167.3
# ep= 9, act0= 3.000, act1= 2.601, vel0= 0.229, vel1= 0.214, rwd= 0.04, scr= -45.14, mt= 55.10, ms= 6.20, d2l= 88.01, d2c= 66.35, noisevar= 0.59, t= 167.4
# ep= 9, act0= 2.811, act1= 2.876, vel0= 0.224, vel1= 0.221, rwd= 0.04, scr= -45.11, mt= 55.10, ms= 6.20, d2l= 87.99, d2c= 66.52, noisevar= 0.59, t= 167.5
# ep= 9, act0= 2.719, act1= 2.185, vel0= 0.218, vel1= 0.193, rwd= 0.04, scr= -45.07, mt= 55.10, ms= 6.20, d2l= 87.98, d2c= 66.40, noisevar= 0.59, t= 167.6
# ep= 9, act0= 3.000, act1= 1.653, vel0= 0.228, vel1= 0.158, rwd= 0.04, scr= -45.03, mt= 55.10, ms= 6.20, d2l= 87.96, d2c= 66.55, noisevar= 0.59, t= 167.7
# ep= 9, act0= 2.612, act1= 2.430, vel0= 0.215, vel1= 0.176, rwd= 0.04, scr= -45.00, mt= 55.10, ms= 6.20, d2l= 87.95, d2c= 66.70, noisevar= 0.59, t= 167.8
# ep= 9, act0= 2.696, act1= 2.963, vel0= 0.213, vel1= 0.208, rwd= 0.04, scr= -44.96, mt= 55.10, ms= 6.20, d2l= 87.93, d2c= 66.16, noisevar= 0.59, t= 167.9
# ep= 9, act0= 2.723, act1= 2.459, vel0= 0.213, vel1= 0.199, rwd= 0.04, scr= -44.92, mt= 55.10, ms= 6.20, d2l= 87.91, d2c= 66.34, noisevar= 0.59, t= 168.0
# ep= 9, act0= 3.000, act1= 1.495, vel0= 0.226, vel1= 0.153, rwd= 0.04, scr= -44.88, mt= 55.10, ms= 6.20, d2l= 87.90, d2c= 66.22, noisevar= 0.59, t= 168.1
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.231, vel1= 0.199, rwd= 0.04, scr= -44.85, mt= 55.10, ms= 6.20, d2l= 87.88, d2c= 66.37, noisevar= 0.59, t= 168.2
# ep= 9, act0= 3.000, act1= 2.911, vel0= 0.233, vel1= 0.215, rwd= 0.04, scr= -44.81, mt= 55.10, ms= 6.20, d2l= 87.86, d2c= 66.26, noisevar= 0.59, t= 168.3
# ep= 9, act0= 2.699, act1= 2.718, vel0= 0.221, vel1= 0.214, rwd= 0.04, scr= -44.77, mt= 55.10, ms= 6.20, d2l= 87.84, d2c= 66.40, noisevar= 0.59, t= 168.4
# ep= 9, act0= 3.000, act1= 2.052, vel0= 0.229, vel1= 0.184, rwd= 0.04, scr= -44.74, mt= 55.10, ms= 6.20, d2l= 87.83, d2c= 66.29, noisevar= 0.59, t= 168.5
# ep= 9, act0= 3.000, act1= 2.130, vel0= 0.232, vel1= 0.174, rwd= 0.04, scr= -44.70, mt= 55.10, ms= 6.20, d2l= 87.81, d2c= 66.44, noisevar= 0.59, t= 168.6
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.234, vel1= 0.208, rwd= 0.04, scr= -44.66, mt= 55.10, ms= 6.20, d2l= 87.79, d2c= 66.32, noisevar= 0.59, t= 168.7
# ep= 9, act0= 3.000, act1= 2.557, vel0= 0.234, vel1= 0.204, rwd= 0.04, scr= -44.62, mt= 55.10, ms= 6.20, d2l= 87.78, d2c= 66.47, noisevar= 0.59, t= 168.8
# ep= 9, act0= 3.000, act1= 2.888, vel0= 0.234, vel1= 0.216, rwd= 0.04, scr= -44.59, mt= 55.10, ms= 6.20, d2l= 87.76, d2c= 66.36, noisevar= 0.59, t= 168.9
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.235, vel1= 0.226, rwd= 0.04, scr= -44.55, mt= 55.10, ms= 6.20, d2l= 87.74, d2c= 65.81, noisevar= 0.59, t= 169.0
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.234, vel1= 0.231, rwd= 0.04, scr= -44.51, mt= 55.10, ms= 6.20, d2l= 87.72, d2c= 65.98, noisevar= 0.59, t= 169.1
# ep= 9, act0= 2.618, act1= 2.799, vel0= 0.218, vel1= 0.224, rwd= 0.04, scr= -44.47, mt= 55.10, ms= 6.20, d2l= 87.70, d2c= 66.13, noisevar= 0.59, t= 169.2
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.227, vel1= 0.230, rwd= 0.04, scr= -44.44, mt= 55.10, ms= 6.20, d2l= 87.68, d2c= 66.02, noisevar= 0.59, t= 169.3
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.231, vel1= 0.232, rwd= 0.04, scr= -44.40, mt= 55.10, ms= 6.20, d2l= 87.66, d2c= 66.16, noisevar= 0.59, t= 169.4
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.233, vel1= 0.233, rwd= 0.04, scr= -44.36, mt= 55.10, ms= 6.20, d2l= 87.63, d2c= 66.05, noisevar= 0.59, t= 169.5
# ep= 9, act0= 2.538, act1= 3.000, vel0= 0.213, vel1= 0.234, rwd= 0.04, scr= -44.32, mt= 55.10, ms= 6.20, d2l= 87.61, d2c= 66.19, noisevar= 0.59, t= 169.6
# ep= 9, act0= 2.199, act1= 3.000, vel0= 0.190, vel1= 0.234, rwd= 0.04, scr= -44.29, mt= 55.10, ms= 6.20, d2l= 87.59, d2c= 66.33, noisevar= 0.59, t= 169.7
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.214, vel1= 0.234, rwd= 0.04, scr= -44.25, mt= 55.10, ms= 6.20, d2l= 87.57, d2c= 65.79, noisevar= 0.59, t= 169.8
# ep= 9, act0= 2.814, act1= 2.381, vel0= 0.217, vel1= 0.207, rwd= 0.04, scr= -44.21, mt= 55.10, ms= 6.20, d2l= 87.55, d2c= 65.96, noisevar= 0.59, t= 169.9
# ep= 9, act0= 3.000, act1= 2.993, vel0= 0.226, vel1= 0.221, rwd= 0.04, scr= -44.17, mt= 55.10, ms= 6.20, d2l= 87.53, d2c= 65.85, noisevar= 0.59, t= 170.0
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.230, vel1= 0.228, rwd= 0.04, scr= -44.14, mt= 55.10, ms= 6.20, d2l= 87.51, d2c= 65.99, noisevar= 0.59, t= 170.1
# ep= 9, act0= 3.000, act1= 2.815, vel0= 0.232, vel1= 0.223, rwd= 0.04, scr= -44.10, mt= 55.10, ms= 6.20, d2l= 87.49, d2c= 65.88, noisevar= 0.59, t= 170.2
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.233, vel1= 0.229, rwd= 0.04, scr= -44.06, mt= 55.10, ms= 6.20, d2l= 87.47, d2c= 66.03, noisevar= 0.59, t= 170.3
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.233, vel1= 0.231, rwd= 0.04, scr= -44.02, mt= 55.10, ms= 6.20, d2l= 87.45, d2c= 65.91, noisevar= 0.59, t= 170.4
# ep= 9, act0= 3.000, act1= 2.493, vel0= 0.233, vel1= 0.210, rwd= 0.04, scr= -43.99, mt= 55.10, ms= 6.20, d2l= 87.44, d2c= 66.06, noisevar= 0.59, t= 170.5
# ep= 9, act0= 2.832, act1= 3.000, vel0= 0.226, vel1= 0.223, rwd= 0.04, scr= -43.95, mt= 55.10, ms= 6.20, d2l= 87.42, d2c= 65.95, noisevar= 0.59, t= 170.6
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.230, vel1= 0.229, rwd= 0.04, scr= -43.91, mt= 55.10, ms= 6.20, d2l= 87.40, d2c= 66.09, noisevar= 0.59, t= 170.7
# ep= 9, act0= 2.897, act1= 2.612, vel0= 0.227, vel1= 0.214, rwd= 0.04, scr= -43.87, mt= 55.10, ms= 6.20, d2l= 87.38, d2c= 65.98, noisevar= 0.59, t= 170.8
# ep= 9, act0= 2.071, act1= 3.000, vel0= 0.190, vel1= 0.225, rwd= 0.04, scr= -43.83, mt= 55.10, ms= 6.20, d2l= 87.36, d2c= 65.43, noisevar= 0.59, t= 170.9
# ep= 9, act0= 1.903, act1= 3.000, vel0= 0.166, vel1= 0.229, rwd= 0.04, scr= -43.80, mt= 55.10, ms= 6.20, d2l= 87.34, d2c= 65.60, noisevar= 0.59, t= 171.0
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.203, vel1= 0.231, rwd= 0.04, scr= -43.76, mt= 55.10, ms= 6.20, d2l= 87.32, d2c= 65.75, noisevar= 0.59, t= 171.1
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.220, vel1= 0.232, rwd= 0.04, scr= -43.72, mt= 55.10, ms= 6.20, d2l= 87.29, d2c= 65.64, noisevar= 0.59, t= 171.2
# ep= 9, act0= 2.867, act1= 2.850, vel0= 0.221, vel1= 0.226, rwd= 0.04, scr= -43.68, mt= 55.10, ms= 6.20, d2l= 87.27, d2c= 65.78, noisevar= 0.59, t= 171.3
# ep= 9, act0= 2.799, act1= 3.000, vel0= 0.219, vel1= 0.229, rwd= 0.04, scr= -43.64, mt= 55.10, ms= 6.20, d2l= 87.25, d2c= 65.67, noisevar= 0.59, t= 171.4
# ep= 9, act0= 3.000, act1= 2.468, vel0= 0.226, vel1= 0.208, rwd= 0.04, scr= -43.61, mt= 55.10, ms= 6.20, d2l= 87.24, d2c= 65.81, noisevar= 0.59, t= 171.5
# ep= 9, act0= 3.000, act1= 1.752, vel0= 0.230, vel1= 0.167, rwd= 0.04, scr= -43.57, mt= 55.10, ms= 6.20, d2l= 87.22, d2c= 65.96, noisevar= 0.59, t= 171.6
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.231, vel1= 0.204, rwd= 0.04, scr= -43.53, mt= 55.10, ms= 6.20, d2l= 87.21, d2c= 65.85, noisevar= 0.59, t= 171.7
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.232, vel1= 0.220, rwd= 0.04, scr= -43.49, mt= 55.10, ms= 6.20, d2l= 87.19, d2c= 65.99, noisevar= 0.59, t= 171.8
# ep= 9, act0= 3.000, act1= 2.547, vel0= 0.232, vel1= 0.207, rwd= 0.04, scr= -43.45, mt= 55.10, ms= 6.20, d2l= 87.17, d2c= 65.88, noisevar= 0.59, t= 171.9
# ep= 9, act0= 2.623, act1= 2.536, vel0= 0.215, vel1= 0.201, rwd= 0.04, scr= -43.42, mt= 55.10, ms= 6.20, d2l= 87.15, d2c= 66.02, noisevar= 0.59, t= 172.0
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.225, vel1= 0.218, rwd= 0.04, scr= -43.38, mt= 55.10, ms= 6.20, d2l= 87.13, d2c= 65.92, noisevar= 0.59, t= 172.1
# ep= 9, act0= 3.000, act1= 2.795, vel0= 0.229, vel1= 0.217, rwd= 0.04, scr= -43.34, mt= 55.10, ms= 6.20, d2l= 87.11, d2c= 66.06, noisevar= 0.59, t= 172.2
# ep= 9, act0= 2.960, act1= 3.000, vel0= 0.228, vel1= 0.225, rwd= 0.04, scr= -43.30, mt= 55.10, ms= 6.20, d2l= 87.09, d2c= 65.95, noisevar= 0.59, t= 172.3
# ep= 9, act0= 3.000, act1= 2.477, vel0= 0.230, vel1= 0.206, rwd= 0.04, scr= -43.27, mt= 55.10, ms= 6.20, d2l= 87.08, d2c= 66.09, noisevar= 0.59, t= 172.4
# ep= 9, act0= 2.795, act1= 2.706, vel0= 0.222, vel1= 0.207, rwd= 0.04, scr= -43.23, mt= 55.10, ms= 6.20, d2l= 87.06, d2c= 66.22, noisevar= 0.59, t= 172.5
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.227, vel1= 0.221, rwd= 0.04, scr= -43.19, mt= 55.10, ms= 6.20, d2l= 87.04, d2c= 65.69, noisevar= 0.59, t= 172.6
# ep= 9, act0= 3.000, act1= 2.821, vel0= 0.229, vel1= 0.219, rwd= 0.04, scr= -43.15, mt= 55.10, ms= 6.20, d2l= 87.02, d2c= 65.86, noisevar= 0.59, t= 172.7
# ep= 9, act0= 2.734, act1= 2.889, vel0= 0.219, vel1= 0.221, rwd= 0.04, scr= -43.12, mt= 55.10, ms= 6.20, d2l= 87.00, d2c= 65.75, noisevar= 0.59, t= 172.8
# ep= 9, act0= 2.762, act1= 2.121, vel0= 0.215, vel1= 0.188, rwd= 0.04, scr= -43.08, mt= 55.10, ms= 6.20, d2l= 86.98, d2c= 65.89, noisevar= 0.59, t= 172.9
# ep= 9, act0= 2.432, act1= 3.000, vel0= 0.199, vel1= 0.212, rwd= 0.04, scr= -43.04, mt= 55.10, ms= 6.20, d2l= 86.97, d2c= 65.36, noisevar= 0.59, t= 173.0
# ep= 9, act0= 2.673, act1= 3.000, vel0= 0.203, vel1= 0.223, rwd= 0.04, scr= -43.00, mt= 55.10, ms= 6.20, d2l= 86.95, d2c= 65.25, noisevar= 0.59, t= 173.1
# ep= 9, act0= 3.000, act1= 2.224, vel0= 0.219, vel1= 0.194, rwd= 0.04, scr= -42.96, mt= 55.10, ms= 6.20, d2l= 86.93, d2c= 65.39, noisevar= 0.59, t= 173.2
# ep= 9, act0= 2.673, act1= 3.000, vel0= 0.211, vel1= 0.215, rwd= 0.04, scr= -42.92, mt= 55.10, ms= 6.20, d2l= 86.91, d2c= 65.29, noisevar= 0.59, t= 173.3
# ep= 9, act0= 2.830, act1= 2.510, vel0= 0.215, vel1= 0.202, rwd= 0.04, scr= -42.88, mt= 55.10, ms= 6.20, d2l= 86.89, d2c= 65.43, noisevar= 0.59, t= 173.4
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.224, vel1= 0.218, rwd= 0.04, scr= -42.85, mt= 55.10, ms= 6.20, d2l= 86.87, d2c= 65.33, noisevar= 0.59, t= 173.5
# ep= 9, act0= 1.696, act1= 3.000, vel0= 0.171, vel1= 0.225, rwd= 0.04, scr= -42.81, mt= 55.10, ms= 6.20, d2l= 86.85, d2c= 65.46, noisevar= 0.59, t= 173.6
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.204, vel1= 0.228, rwd= 0.04, scr= -42.77, mt= 55.10, ms= 6.20, d2l= 86.83, d2c= 65.60, noisevar= 0.59, t= 173.7
# ep= 9, act0= 3.000, act1= 3.000, vel0= 0.219, vel1= 0.229, rwd= 0.04, scr= -42.73, mt= 55.10, ms= 6.20, d2l= 86.81, d2c= 65.07, noisevar= 0.59, t= 173.8
# ep= 9, act0= 2.619, act1= 3.000, vel0= 0.209, vel1= 0.230, rwd= 0.04, scr= -42.69, mt= 55.10, ms= 6.20, d2l= 86.79, d2c= 65.24, noisevar= 0.59, t= 173.9
# ep= 9, act0= 3.000, act1= 2.756, vel0= 0.221, vel1= 0.219, rwd= 0.04, scr= -42.65, mt= 55.10, ms= 6.20, d2l= 86.77, d2c= 65.13, noisevar= 0.59, t= 174.0
# ep= 9, act0= 2.123, act1= 2.156, vel0= 0.188, vel1= 0.189, rwd= 0.04, scr= -42.62, mt= 55.10, ms= 6.20, d2l= 86.76, d2c= 65.27, noisevar= 0.59, t= 174.1
# ep= 9, act0= 2.385, act1= 3.000, vel0= 0.185, vel1= 0.212, rwd= 0.04, scr= -42.58, mt= 55.10, ms= 6.20, d2l= 86.74, d2c= 65.17, noisevar= 0.59, t= 174.2
# ep= 9, act0= 2.803, act1= 3.000, vel0= 0.202, vel1= 0.222, rwd= 0.04, scr= -42.54, mt= 55.10, ms= 6.20, d2l= 86.72, d2c= 65.31, noisevar= 0.59, t= 174.3
# ep= 9, act0= 2.807, act1= 3.000, vel0= 0.209, vel1= 0.226, rwd= 0.04, scr= -42.50, mt= 55.10, ms= 6.20, d2l= 86.70, d2c= 65.20, noisevar= 0.59, t= 174.4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 19
#      16 for dim in range(particles.dim):
#      17     particles.member[rlagent]['deltavel'][str(dim)] = action[int(dim)]
# ---> 19 particles.update(keepGoing=not done)
#      20 distance = {'2leader'  : (lambda x: np.sqrt(x[0]**2+x[1]**2))\
#      21                          (list(particles.member[rlagent]['distance2leader'].values())),
#      22             '2closest' : particles.member[rlagent]['abs_distance_sorted'][1]}
#      23 newstate = stateappend(newstate)
#
# File /home/reinforcement-learning/src/swarm.py:194, in swarm.update(self, keepGoing)
#     192 if self.keepGoing:
#     193     self.__display()
# --> 194     self.__distance()
#
# File /home/reinforcement-learning/src/swarm.py:96, in swarm.__distance(self)
#      88 self.member[str(ii)]['distance']            = {str(jj): {str(kk): self.member[str(ii)]['position'][str(kk)]-\
#      89                                                                   self.member[str(jj)]['position'][str(kk)] \
#      90                                                                   for kk in range(self.dim)} \
#      91                                                         for jj in range(self.nop)}
#      93 self.member[str(ii)]['distance_sorted']     = {str(jj): sorted(np.abs(self.member[str(ii)]['distance'][str(kk)][str(jj)])\
#      94                                                         for kk in range(self.nop)) for jj in range(self.dim)}
# ---> 96 self.member[str(ii)]['abs_distance']        = {str(jj): np.sqrt(math.fsum(self.member[str(ii)]['distance'][str(jj)][str(kk)]**2\
#      97                                                         for kk in range(self.dim))) for jj in range(self.nop)}
#      99 self.member[str(ii)]['abs_distance_sorted'] = [sorted(self.member[str(ii)]['abs_distance'].items(), \
#     100                                                key = lambda kv:(kv[1], kv[0]))[jj][1] for jj in range(self.nop)]
#     102 self.member[str(ii)]['closest_neighbours']  = [sorted(self.member[str(ii)]['abs_distance'].items(), \
#     103                                                key = lambda kv:(kv[1], kv[0]))[jj][0] for jj in range(self.nop)]
#
# File /home/reinforcement-learning/src/swarm.py:96, in <dictcomp>(.0)
#      88 self.member[str(ii)]['distance']            = {str(jj): {str(kk): self.member[str(ii)]['position'][str(kk)]-\
#      89                                                                   self.member[str(jj)]['position'][str(kk)] \
#      90                                                                   for kk in range(self.dim)} \
#      91                                                         for jj in range(self.nop)}
#      93 self.member[str(ii)]['distance_sorted']     = {str(jj): sorted(np.abs(self.member[str(ii)]['distance'][str(kk)][str(jj)])\
#      94                                                         for kk in range(self.nop)) for jj in range(self.dim)}
# ---> 96 self.member[str(ii)]['abs_distance']        = {str(jj): np.sqrt(math.fsum(self.member[str(ii)]['distance'][str(jj)][str(kk)]**2\
#      97                                                         for kk in range(self.dim))) for jj in range(self.nop)}
#      99 self.member[str(ii)]['abs_distance_sorted'] = [sorted(self.member[str(ii)]['abs_distance'].items(), \
#     100                                                key = lambda kv:(kv[1], kv[0]))[jj][1] for jj in range(self.nop)]
#     102 self.member[str(ii)]['closest_neighbours']  = [sorted(self.member[str(ii)]['abs_distance'].items(), \
#     103                                                key = lambda kv:(kv[1], kv[0]))[jj][0] for jj in range(self.nop)]
#
# KeyboardInterrupt:
